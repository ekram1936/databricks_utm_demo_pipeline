# %%
import sys
sys.path.append("/Workspace/Users/md-ekram.hossain@stud.uni-bamberg.de/databricks_utm_demo_pipeline") # match your actual Git folder path

from src.pipeline import stream_bronze_ingest
from src.utils.logger import get_logger

logger = get_logger("run_streaming")
logger.info("Starting always-on Event Hubs streaming ingestion job...")

query = stream_bronze_ingest.run(spark, dbutils, await_termination=True)
